# %%
def tas_kagıt_makas_EsraN () :
    import random
    secenekler= ("tas","kagıt","makas")
    player_w = 0
    comp_w = 0
    game = 1
    round = 0
    player_rw = 0
    comp_rw = 0 
    print("######" "  TAŞ-KAĞIT-MAKAS OYUNU  " "######" )
    print("\nTaş-kâğıt-makas, genellikle iki oyuncuyla ve üç durumdan birinin seçilmesiyle oynanan bir oyunudur." "\nTaş makası, makas kağıdı, kâğıt da taşı yener." "\nEğer oyuncular aynı durumu seçerse oyun berabere biter.""\nÜç roundan ikisini kazanan oyunu kazanır.")
    while player_w<2 and comp_w <2:
        round += 1
        
        print("\n" "<<< " "GAME :", game ," ROUND :",round , ">>>")
        
        while True :
            player = str(input("Lütfen birini seçiniz (tas,kagıt,makas) :"))
            if player == "tas" or player == "kagıt" or player == "makas":
                break
            else :
                print("Lütfen şıklaradan birini giriniz :")
    
        comp= random.choice (secenekler)
        print("Player :",player)
        print("Computer :", comp)
        
        if player == "makas" and comp == "kagıt":
            player_w = 1+player_w 
    
            print("Player =",player_w)
            print("Computer =", comp_w)
            print(" You win! :)) ")
        elif player == "kagıt" and comp == "tas":
            player_w = 1+player_w 
    
            print(" You win! :)) ")
            print("Player =",player_w)
            print("Computer =", comp_w)
        elif player == "tas" and comp == "makas":
            player_w = 1+ player_w 
    
            print("Player =",player_w)
            print("Computer =", comp_w)
            print(" You win! :)) ")
           
        elif player == comp :
    
            print(" It's a tie ")
            print("Player =" , player_w)
            print("Computer =",comp_w)
        else : 
            comp_w += 1
    
            print("Computer =", comp_w)
            print("Player =", player_w)
            print(" You lose! :(( ") 
        
        if player_w == 2 or comp_w == 2:
            
            print("\n""Yeniden oynamak ister misin?")
            
            while True :
                player = str(input("evet ,hayır ya da cıkıs : " ))
                if player == "evet" or player == "hayır" or player == "cıkıs":
                 break
                else :
                    print("Lütfen şıklaradan birini giriniz : ")
            options = ("evet" , "hayır", "cıkıs" )
            comp_c= random.choice(options)
                    
        if player == "evet" and comp_c== "evet" :
            print ("Hadi bir daha oynayalım")
            game += 1
            player_w = 0
            comp_w = 0
            round = 0
        elif player == "evet" and  comp_c== "hayır":
            print("Üzgünüm, ben oynamak istemiyorum. :((" ) 
        elif player == "hayır"  and comp_c== "hayır":
            print("Oyun bitti. Güzel oyundu. Teşşekkürler :))")   
        elif player == "cıkıs" and comp_c == "cıkıs":
            print("Oyun İçin teşşekürler")
        elif player == "hayır" and comp_c == "evet" : 
            print("Ben oynamak istiyordum. :((" ) 
        elif player == "evet" and comp_c== "cıkıs" :
            print("Bana bu kadar oyun yeter. Başka zaman tekrar gel.")
        elif player == "cıkıs" and comp_c == "evet":
            print("İstediğin zaman tekar gel ;)")
        elif player == "cıkıs" and comp_c == "hayır":
            print("ikimizde oynamak istemiyoruz daha fazla. :)")
        elif player == "hayır" and comp_c == "cıkıs":
            print("Sanırım ikimizde oynamak istemiyoruz daha fazla. :)")
        
        
            
            break
